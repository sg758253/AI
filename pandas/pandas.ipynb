# %% [markdown]
# <a href="https://colab.research.google.com/github/sg758253/AI/blob/main/pandas/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  # pandas data structure:
# 1. Series- one dimensional labeled homogeneous array
# 2. Dataframe: 2d dimensional,heterogeneous,size mutable, tabular structure with labeled axes (rows & columns) (series+series=dataframe)
# 3. Panel- 3d labeled array
#
# # Pandas vs numpy
# Numpy is used for the implementation of pandas data objects.
#
# # installation
# pip install pandas, if you are not using jupyter,spyder

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.3.5'

# %%
list_s = [1,2,-3,6.2,'data values']
list_s
# Out:
# [1, 2, -3, 6.2, 'data values']

# %%
type(list_s)
# Out:
# list

# %% [markdown]
# # Series

# %%
series1 = pd.Series(list_s)
series1
# Out:
# 0              1
# 1              2
# 2             -3
# 3            6.2
# 4    data values
# dtype: object

# %%
type(series1)
# Out:
# pandas.core.series.Series

# %%
series2 = pd.Series([1,2,3,4])
series2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#empty_s = pd.Series()
empty_s = pd.Series([])
empty_s
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# Series([], dtype: float64)

# %%
series2 = pd.Series([1,2,3,4],index=['a','b','c'])
series2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-9a5ebb591d7f> in <module>()
# ----> 1 series2 = pd.Series([1,2,3,4],index=['a','b','c'])
#       2 series2
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     428                 index = ibase.default_index(len(data))
#     429             elif is_list_like(data):
# --> 430                 com.require_length_match(data, index)
#     431
#     432             # create/copy the manager
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     530     if len(data) != len(index):
#     531         raise ValueError(
# --> 532             "Length of values "
#     533             f"({len(data)}) "
#     534             "does not match length of index "
#
# ...

# %%
series2 = pd.Series([1,2,3,4],index=['a','b','c','d'])
series2
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
series2 = pd.Series([1,2,3,4],index=['a','b','c','d'],dtype=float)
series2
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %%
series2 = pd.Series([1,2,3,4],index=['a','b','c','d'],dtype=float,name='my data values')
series2
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# Name: my data values, dtype: float64

# %%
scaler_s = pd.Series(0.5)
scaler_s
# Out:
# 0    0.5
# dtype: float64

# %%
scaler_s = pd.Series(0.5,index=[1,2,3])
scaler_s
# Out:
# 1    0.5
# 2    0.5
# 3    0.5
# dtype: float64

# %%
dict_s = pd.Series({'a':1,'b':2})
dict_s
# Out:
# a    1
# b    2
# dtype: int64

# %%
s4 = pd.Series([1,2,3,4,5])
s4
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s4[0:3]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
max(s4)
# Out:
# 5

# %%
min(s4)
# Out:
# 1

# %%
s4[s4>3]
# Out:
# 3    4
# 4    5
# dtype: int64

# %%
s5 = pd.Series([1,2,3,4,5])
s5
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s4+s5
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
s6 = pd.Series([1,2,3])
s6
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
# unequal data series
s5+s6
# Out:
# 0    2.0
# 1    4.0
# 2    6.0
# 3    NaN
# 4    NaN
# dtype: float64

# %% [markdown]
# # Dataframe

# %%
df1 = pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print(df1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1 = pd.DataFrame(['a','b','c'])
df1
# Out:
#    0
# 0  a
# 1  b
# 2  c

# %%
df2 = pd.DataFrame([['1','2','3'],['2','3','4']])
df2
# Out:
#    0  1  2
# 0  1  2  3
# 1  2  3  4

# %%
# ValueError: All arrays must be of the same length
df3 = pd.DataFrame({'id':[1,2,3],'name':['a','b']})
df3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-dfb7ecfc588e> in <module>()
#       1 # ValueError: All arrays must be of the same length
# ----> 2 df3 = pd.DataFrame({'id':[1,2,3],'name':['a','b']})
#       3 df3
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
#     464     return arrays_to_mgr(
# ...

# %%
df3 = pd.DataFrame({'id':[1,2,3],'name':['a','b','c']})
df3
# Out:
#    id name
# 0   1    a
# 1   2    b
# 2   3    c

# %%
# list of dict
df4= pd.DataFrame([{'a':1,'b':2},{'c':3,'d':4}])
df4
# Out:
#      a    b    c    d
# 0  1.0  2.0  NaN  NaN
# 1  NaN  NaN  3.0  4.0

# %%
# list of dict
df4= pd.DataFrame([{'a':1,'b':2},{'a':3,'b':4}])
df4
# Out:
#    a  b
# 0  1  2
# 1  3  4

# %%
dict_sr = {'Id':pd.Series([1,2,3]),'SN':pd.Series([11,22,33])}
df5 = pd.DataFrame(dict_sr)
df5
# Out:
#    Id  SN
# 0   1  11
# 1   2  22
# 2   3  33

# %% [markdown]
# # read_csv

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1
# Out:
#     gender parental level of education         lunch  math score  \
# 0   female           bachelor's degree      standard        72.0
# 1   female                some college      standard        69.0
# 2   female             master's degree      standard         NaN
# 3     male          associate's degree  free/reduced        47.0
# 4     male                         NaN           NaN         NaN
# 5   female          associate's degree           NaN        71.0
# 6   female                some college      standard         0.0
# 7     male                some college  free/reduced        40.0
# 8     male                 high school  free/reduced        64.0
# 9   female                 high school  free/reduced         NaN
# 10    male          associate's degree      standard        58.0
# 11    male          associate's degree      standard        40.0
# 12  female                 high school      standard        65.0
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.columns
# Out:
# Index(['gender', 'parental level of education', 'lunch', 'math score',
#        'reading score', 'writing score', 'Date'],
#       dtype='object')

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',nrows=1)
df1
# Out:
#    gender parental level of education     lunch  math score  reading score  \
# 0  female           bachelor's degree  standard          72             72
#
#    writing score        Date
# 0             74  03-13-2022

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',usecols=[0,3])
df1
# Out:
#     gender  math score
# 0   female        72.0
# 1   female        69.0
# 2   female         NaN
# 3     male        47.0
# 4     male         NaN
# 5   female        71.0
# 6   female         0.0
# 7     male        40.0
# 8     male        64.0
# 9   female         NaN
# 10    male        58.0
# 11    male        40.0
# 12  female        65.0
# 13    male        78.0
# 14  female        50.0
# 15  female        69.0
# 16    male        88.0
# 17  female        18.0

# %%
#skip number of rows from top
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',skiprows=1)
df1.head(4)
# Out:
#    female   bachelor's degree      standard    72  72.1    74  03-13-2022
# 0  female        some college      standard  69.0  90.0  88.0  03-14-2022
# 1  female     master's degree      standard   NaN   NaN   NaN  03-15-2022
# 2    male  associate's degree  free/reduced  47.0  57.0  44.0  03-13-2022
# 3    male                 NaN           NaN   NaN  78.0   NaN         NaN

# %%
#skip specific rows
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',skiprows=[2,3,4,5])
df1
# Out:
#     gender parental level of education         lunch  math score  \
# 0   female           bachelor's degree      standard        72.0
# 1   female          associate's degree           NaN        71.0
# 2   female                some college      standard         0.0
# 3     male                some college  free/reduced        40.0
# 4     male                 high school  free/reduced        64.0
# 5   female                 high school  free/reduced         NaN
# 6     male          associate's degree      standard        58.0
# 7     male          associate's degree      standard        40.0
# 8   female                 high school      standard        65.0
# 9     male                some college      standard        78.0
# 10  female             master's degree      standard        50.0
# 11  female            some high school      standard        69.0
# 12    male                 high school      standard        88.0
# ...

# %%
#create index col
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',index_col='gender')
df1.head(3)
# Out:
#        parental level of education     lunch  math score  reading score  \
# gender
# female           bachelor's degree  standard        72.0           72.0
# female                some college  standard        69.0           90.0
# female             master's degree  standard         NaN            NaN
#
#         writing score        Date
# gender
# female           74.0  03-13-2022
# female           88.0  03-14-2022
# female            NaN  03-15-2022

# %%
#create index col
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',index_col=3)
df1.head(3)
# Out:
#             gender parental level of education     lunch  reading score  \
# math score
# 72.0        female           bachelor's degree  standard           72.0
# 69.0        female                some college  standard           90.0
# NaN         female             master's degree  standard            NaN
#
#             writing score        Date
# math score
# 72.0                 74.0  03-13-2022
# 69.0                 88.0  03-14-2022
# NaN                   NaN  03-15-2022

# %%
#create index col
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',index_col=[2,3])
df1.head(3)
# Out:
#                      gender parental level of education  reading score  \
# lunch    math score
# standard 72.0        female           bachelor's degree           72.0
#          69.0        female                some college           90.0
#          NaN         female             master's degree            NaN
#
#                      writing score        Date
# lunch    math score
# standard 72.0                 74.0  03-13-2022
#          69.0                 88.0  03-14-2022
#          NaN                   NaN  03-15-2022

# %%
#assign specific rows as header
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',header=1)
df1.head(3)
# Out:
#    female   bachelor's degree      standard    72  72.1    74  03-13-2022
# 0  female        some college      standard  69.0  90.0  88.0  03-14-2022
# 1  female     master's degree      standard   NaN   NaN   NaN  03-15-2022
# 2    male  associate's degree  free/reduced  47.0  57.0  44.0  03-13-2022

# %%
#set header none
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',header=None)
df1.head(3)
# Out:
#         0                            1         2           3              4  \
# 0  gender  parental level of education     lunch  math score  reading score
# 1  female            bachelor's degree  standard          72             72
# 2  female                 some college  standard          69             90
#
#                5           6
# 0  writing score        Date
# 1             74  03-13-2022
# 2             88  03-14-2022

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv', prefix='columns')
df1.head(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-9dfd8f65686b> in <module>()
# ----> 1 df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv', prefix='columns')
#       2 df1.head(3)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',header=None, prefix='col')
df1.head(3)
# Out:
#      col0                         col1      col2        col3           col4  \
# 0  gender  parental level of education     lunch  math score  reading score
# 1  female            bachelor's degree  standard          72             72
# 2  female                 some college  standard          69             90
#
#             col5        col6
# 0  writing score        Date
# 1             74  03-13-2022
# 2             88  03-14-2022

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',names=['a','b','c','d','e','f','g'])
df1.head(3)
# Out:
#         a                            b         c           d              e  \
# 0  gender  parental level of education     lunch  math score  reading score
# 1  female            bachelor's degree  standard          72             72
# 2  female                 some college  standard          69             90
#
#                f           g
# 0  writing score        Date
# 1             74  03-13-2022
# 2             88  03-14-2022

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',names=['a','b','c','d','e','f','g','h'])
df1.head(3)
# Out:
#         a                            b         c           d              e  \
# 0  gender  parental level of education     lunch  math score  reading score
# 1  female            bachelor's degree  standard          72             72
# 2  female                 some college  standard          69             90
#
#                f           g   h
# 0  writing score        Date NaN
# 1             74  03-13-2022 NaN
# 2             88  03-14-2022 NaN

# %%
df1.tail()
# Out:
#          a                 b             c   d   e   f           g   h
# 14    male      some college      standard  78  72  70  03-14-2022 NaN
# 15  female   master's degree      standard  50  53  58  03-15-2022 NaN
# 16  female  some high school      standard  69  75  78  03-13-2022 NaN
# 17    male       high school      standard  88  89  86  03-14-2022 NaN
# 18  female  some high school  free/reduced  18  32  28  03-15-2022 NaN

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',dtype={'gender':'float64'})
df1.head(3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-b40b19e464ea> in <module>()
# ----> 1 df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',dtype={'gender':'float64'})
#       2 df1.head(3)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',dtype={'writing score':'float64'})
df1.head(3)
# Out:
#    gender parental level of education     lunch  math score  reading score  \
# 0  female           bachelor's degree  standard        72.0           72.0
# 1  female                some college  standard        69.0           90.0
# 2  female             master's degree  standard         NaN            NaN
#
#    writing score        Date
# 0           74.0  03-13-2022
# 1           88.0  03-14-2022
# 2            NaN  03-15-2022

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',true_values=['female'],false_values=['male'])
df1.head(5)
# Out:
#    gender parental level of education         lunch  math score  \
# 0    True           bachelor's degree      standard        72.0
# 1    True                some college      standard        69.0
# 2    True             master's degree      standard         NaN
# 3   False          associate's degree  free/reduced        47.0
# 4   False                         NaN           NaN         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# 4           78.0            NaN         NaN

# %% [markdown]
# # Handling missing value

# %%
# Nan =missing values
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
# Nan =missing values
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',na_values='not available')
df1.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',na_values=['not available','not value'])
df1.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',na_values={'writing score':'not available','math score':'not value'})
df1.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',keep_default_na=False)
df1.head(10)
# Out:
#    gender parental level of education         lunch math score reading score  \
# 0  female           bachelor's degree      standard         72            72
# 1  female                some college      standard         69            90
# 2  female             master's degree      standard
# 3    male          associate's degree  free/reduced         47            57
# 4    male                                                                 78
# 5  female          associate's degree                       71            83
# 6  female                some college      standard          0            95
# 7    male                some college  free/reduced         40            43
# 8    male                 high school  free/reduced         64            64
# 9  female                 high school  free/reduced                       60
#
#   writing score        Date
# 0            74  03-13-2022
# 1            88  03-14-2022
# 2                03-15-2022
# 3            44  03-13-2022
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',na_filter=False)
df1.head(10)
# Out:
#    gender parental level of education         lunch math score reading score  \
# 0  female           bachelor's degree      standard         72            72
# 1  female                some college      standard         69            90
# 2  female             master's degree      standard
# 3    male          associate's degree  free/reduced         47            57
# 4    male                                                                 78
# 5  female          associate's degree                       71            83
# 6  female                some college      standard          0            95
# 7    male                some college  free/reduced         40            43
# 8    male                 high school  free/reduced         64            64
# 9  female                 high school  free/reduced                       60
#
#   writing score        Date
# 0            74  03-13-2022
# 1            88  03-14-2022
# 2                03-15-2022
# 3            44  03-13-2022
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',na_values=['not available','not value'])
df1.isnull()
# Out:
#     gender  parental level of education  lunch  math score  reading score  \
# 0    False                        False  False       False          False
# 1    False                        False  False       False          False
# 2    False                        False  False        True           True
# 3    False                        False  False       False          False
# 4    False                         True   True        True          False
# 5    False                        False   True       False          False
# 6    False                        False  False       False          False
# 7    False                        False  False       False          False
# 8    False                        False  False       False          False
# 9    False                        False  False        True          False
# 10   False                        False  False       False          False
# 11   False                        False  False       False          False
# ...

# %%
df1.isnull().sum()
# Out:
# gender                         0
# parental level of education    1
# lunch                          2
# math score                     3
# reading score                  1
# writing score                  4
# Date                           1
# dtype: int64

# %%
df1.isnull().sum().sum()
# Out:
# 12

# %%
df1.notnull()
# Out:
#     gender  parental level of education  lunch  math score  reading score  \
# 0     True                         True   True        True           True
# 1     True                         True   True        True           True
# 2     True                         True   True       False          False
# 3     True                         True   True        True           True
# 4     True                        False  False       False           True
# 5     True                         True  False        True           True
# 6     True                         True   True        True           True
# 7     True                         True   True        True           True
# 8     True                         True   True        True           True
# 9     True                         True   True       False           True
# 10    True                         True   True        True           True
# 11    True                         True   True        True           True
# ...

# %%
df1.notnull().sum()
# Out:
# gender                         18
# parental level of education    17
# lunch                          16
# math score                     15
# reading score                  17
# writing score                  14
# Date                           17
# dtype: int64

# %%
df1.notnull().sum().sum()
# Out:
# 114

# %% [markdown]
# # Drop

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',na_values=['not available','not value'])
df1
# Out:
#     gender parental level of education         lunch  math score  \
# 0   female           bachelor's degree      standard        72.0
# 1   female                some college      standard        69.0
# 2   female             master's degree      standard         NaN
# 3     male          associate's degree  free/reduced        47.0
# 4     male                         NaN           NaN         NaN
# 5   female          associate's degree           NaN        71.0
# 6   female                some college      standard         0.0
# 7     male                some college  free/reduced        40.0
# 8     male                 high school  free/reduced        64.0
# 9   female                 high school  free/reduced         NaN
# 10    male          associate's degree      standard        58.0
# 11    male          associate's degree      standard        40.0
# 12  female                 high school      standard        65.0
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.dropna()
# Out:
#     gender parental level of education         lunch  math score  \
# 0   female           bachelor's degree      standard        72.0
# 1   female                some college      standard        69.0
# 3     male          associate's degree  free/reduced        47.0
# 6   female                some college      standard         0.0
# 7     male                some college  free/reduced        40.0
# 10    male          associate's degree      standard        58.0
# 11    male          associate's degree      standard        40.0
# 12  female                 high school      standard        65.0
# 13    male                some college      standard        78.0
# 14  female             master's degree      standard        50.0
# 15  female            some high school      standard        69.0
# 16    male                 high school      standard        88.0
# 17  female            some high school  free/reduced        18.0
#
#     reading score  writing score        Date
# ...

# %%
#column
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.dropna(axis=1)
# Out:
#     gender
# 0   female
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7     male
# 8     male
# 9   female
# 10    male
# 11    male
# 12  female
# 13    male
# 14  female
# 15  female
# 16    male
# 17  female

# %%
#remove rows/collumn if any single value is missing
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.dropna(how='any')
# Out:
#     gender parental level of education         lunch  math score  \
# 0   female           bachelor's degree      standard        72.0
# 1   female                some college      standard        69.0
# 3     male          associate's degree  free/reduced        47.0
# 6   female                some college      standard         0.0
# 7     male                some college  free/reduced        40.0
# 10    male          associate's degree      standard        58.0
# 11    male          associate's degree      standard        40.0
# 12  female                 high school      standard        65.0
# 13    male                some college      standard        78.0
# 14  female             master's degree      standard        50.0
# 15  female            some high school      standard        69.0
# 16    male                 high school      standard        88.0
# 17  female            some high school  free/reduced        18.0
#
#     reading score  writing score        Date
# ...

# %%
#remove rows/collumn if all values are missing
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.dropna(how='all')
# Out:
#     gender parental level of education         lunch  math score  \
# 0   female           bachelor's degree      standard        72.0
# 1   female                some college      standard        69.0
# 2   female             master's degree      standard         NaN
# 3     male          associate's degree  free/reduced        47.0
# 4     male                         NaN           NaN         NaN
# 5   female          associate's degree           NaN        71.0
# 6   female                some college      standard         0.0
# 7     male                some college  free/reduced        40.0
# 8     male                 high school  free/reduced        64.0
# 9   female                 high school  free/reduced         NaN
# 10    male          associate's degree      standard        58.0
# 11    male          associate's degree      standard        40.0
# 12  female                 high school      standard        65.0
# ...

# %%
# atleast 1 not null values
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.dropna(thresh=1)
# Out:
#     gender parental level of education         lunch  math score  \
# 0   female           bachelor's degree      standard        72.0
# 1   female                some college      standard        69.0
# 2   female             master's degree      standard         NaN
# 3     male          associate's degree  free/reduced        47.0
# 4     male                         NaN           NaN         NaN
# 5   female          associate's degree           NaN        71.0
# 6   female                some college      standard         0.0
# 7     male                some college  free/reduced        40.0
# 8     male                 high school  free/reduced        64.0
# 9   female                 high school  free/reduced         NaN
# 10    male          associate's degree      standard        58.0
# 11    male          associate's degree      standard        40.0
# 12  female                 high school      standard        65.0
# ...

# %%
# drop rows of specific column
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.dropna(subset=['writing score'])
# Out:
#     gender parental level of education         lunch  math score  \
# 0   female           bachelor's degree      standard        72.0
# 1   female                some college      standard        69.0
# 3     male          associate's degree  free/reduced        47.0
# 5   female          associate's degree           NaN        71.0
# 6   female                some college      standard         0.0
# 7     male                some college  free/reduced        40.0
# 10    male          associate's degree      standard        58.0
# 11    male          associate's degree      standard        40.0
# 12  female                 high school      standard        65.0
# 13    male                some college      standard        78.0
# 14  female             master's degree      standard        50.0
# 15  female            some high school      standard        69.0
# 16    male                 high school      standard        88.0
# ...

# %%
# update on same dataframe.
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.dropna(inplace=True)
df1
# Out:
#     gender parental level of education         lunch  math score  \
# 0   female           bachelor's degree      standard        72.0
# 1   female                some college      standard        69.0
# 3     male          associate's degree  free/reduced        47.0
# 6   female                some college      standard         0.0
# 7     male                some college  free/reduced        40.0
# 10    male          associate's degree      standard        58.0
# 11    male          associate's degree      standard        40.0
# 12  female                 high school      standard        65.0
# 13    male                some college      standard        78.0
# 14  female             master's degree      standard        50.0
# 15  female            some high school      standard        69.0
# 16    male                 high school      standard        88.0
# 17  female            some high school  free/reduced        18.0
#
#     reading score  writing score        Date
# ...

# %% [markdown]
# # FillNa

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
#fill by scaler value (single value)
df1.fillna(0)
# Out:
#     gender parental level of education         lunch  math score  \
# 0   female           bachelor's degree      standard        72.0
# 1   female                some college      standard        69.0
# 2   female             master's degree      standard         0.0
# 3     male          associate's degree  free/reduced        47.0
# 4     male                           0             0         0.0
# 5   female          associate's degree             0        71.0
# 6   female                some college      standard         0.0
# 7     male                some college  free/reduced        40.0
# 8     male                 high school  free/reduced        64.0
# 9   female                 high school  free/reduced         0.0
# 10    male          associate's degree      standard        58.0
# 11    male          associate's degree      standard        40.0
# 12  female                 high school      standard        65.0
# ...

# %%
#fill by scaler value on each specific column
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.fillna({'parental level of education':'some college', 'lunch':'standard', 'writing score':2},inplace=True)
df1.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                some college      standard         NaN
# 5  female          associate's degree      standard        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            2.0  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
#fill next value
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.fillna(inplace=True,method='ffill')
df1.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard        69.0
# 3    male          associate's degree  free/reduced        47.0
# 4    male          associate's degree  free/reduced        47.0
# 5  female          associate's degree  free/reduced        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced        64.0
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2           90.0           88.0  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
#fill next value
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.fillna(inplace=True,method='pad')
df1.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard        69.0
# 3    male          associate's degree  free/reduced        47.0
# 4    male          associate's degree  free/reduced        47.0
# 5  female          associate's degree  free/reduced        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced        64.0
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2           90.0           88.0  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
#fill back value
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.fillna(inplace=True,method='bfill')
df1.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard        47.0
# 3    male          associate's degree  free/reduced        47.0
# 4    male          associate's degree      standard        71.0
# 5  female          associate's degree      standard        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced        58.0
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2           57.0           44.0  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
#error: Must specify a fill 'value' or 'method'.
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.fillna(axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-1578ea75e927> in <module>()
#       1 #error: Must specify a fill 'value' or 'method'.
#       2 df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
# ----> 3 df1.fillna(axis=0)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    5180             inplace=inplace,
#    5181             limit=limit,
# -> 5182             downcast=downcast,
#    5183         )
#    5184
#
# ...

# %%
# 
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2=df1.fillna(axis=1, method='ffill')
df2.head(10)
# Out:
#    gender parental level of education               lunch    math score  \
# 0  female           bachelor's degree            standard          72.0
# 1  female                some college            standard          69.0
# 2  female             master's degree            standard      standard
# 3    male          associate's degree        free/reduced          47.0
# 4    male                        male                male          male
# 5  female          associate's degree  associate's degree          71.0
# 6  female                some college            standard           0.0
# 7    male                some college        free/reduced          40.0
# 8    male                 high school        free/reduced          64.0
# 9  female                 high school        free/reduced  free/reduced
#
#   reading score writing score        Date
# 0          72.0          74.0  03-13-2022
# 1          90.0          88.0  03-14-2022
# 2      standard      standard  03-15-2022
# ...

# %%
# on same dataframe, due to datatype values can't be change 
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1.fillna(inplace=True,axis=1, method='ffill')
df1.head(10)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-89-e28abe304a0b> in <module>()
#       1 # on same dataframe, due to datatype values can't be change
#       2 df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
# ----> 3 df1.fillna(inplace=True,axis=1, method='ffill')
#       4 df1.head(10)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    5180             inplace=inplace,
#    5181             limit=limit,
# -> 5182             downcast=downcast,
# ...

# %%
# limit should greate than zero, value or method must be specify
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2=df1.fillna(0,limit=1)
df2.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard         0.0
# 3    male          associate's degree  free/reduced        47.0
# 4    male                           0             0         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            0.0            0.0  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
# limit should greate than zero. value or method must be specify
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2=df1.fillna(method='ffill',limit=2)
df2.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard        69.0
# 3    male          associate's degree  free/reduced        47.0
# 4    male          associate's degree  free/reduced        47.0
# 5  female          associate's degree  free/reduced        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced        64.0
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2           90.0           88.0  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %% [markdown]
# # Replace

# %%
# 
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df1
# Out:
#     gender parental level of education         lunch  math score  \
# 0   female           bachelor's degree      standard        72.0
# 1   female                some college      standard        69.0
# 2   female             master's degree      standard         NaN
# 3     male          associate's degree  free/reduced        47.0
# 4     male                         NaN           NaN         NaN
# 5   female          associate's degree           NaN        71.0
# 6   female                some college      standard         0.0
# 7     male                some college  free/reduced        40.0
# 8     male                 high school  free/reduced        64.0
# 9   female                 high school  free/reduced         NaN
# 10    male          associate's degree      standard        58.0
# 11    male          associate's degree      standard        40.0
# 12  female                 high school      standard        65.0
# ...

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2 = df1.replace(to_replace='some college',value='bachelors degree')
df2.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female            bachelors degree      standard        69.0
# 2  female             master's degree      standard         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female            bachelors degree      standard         0.0
# 7    male            bachelors degree  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
# paramter are in sequence
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2 = df1.replace('some college','bachelors degree')
df2.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female            bachelors degree      standard        69.0
# 2  female             master's degree      standard         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female            bachelors degree      standard         0.0
# 7    male            bachelors degree  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
# replace all values by single value
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2 = df1.replace([0,1,2,3,4,5,6],'bachelors degree')
df2.head(10)
# Out:
#    gender parental level of education         lunch        math score  \
# 0  female           bachelor's degree      standard              72.0
# 1  female                some college      standard              69.0
# 2  female             master's degree      standard               NaN
# 3    male          associate's degree  free/reduced              47.0
# 4    male                         NaN           NaN               NaN
# 5  female          associate's degree           NaN              71.0
# 6  female                some college      standard  bachelors degree
# 7    male                some college  free/reduced              40.0
# 8    male                 high school  free/reduced              64.0
# 9  female                 high school  free/reduced               NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# ...

# %%
# replace all values by multiple values
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2 = df1.replace([0,1,2,3,4,5,6],[10,11,12,13,14,15,16])
df2.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female                some college      standard        10.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
# replace all values by multiple values
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2 = df1.replace({'lunch':'standard'},'none')
df2.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree          none        72.0
# 1  female                some college          none        69.0
# 2  female             master's degree          none         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female                some college          none         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
# doesn't work
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2 = df1.replace('[A-Za-z]',0)
df2.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
# regex
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2 = df1.replace('[A-Za-z]',0,regex=True)
df2.head(10)
# Out:
#   gender parental level of education lunch  math score  reading score  \
# 0      0                           0     0        72.0           72.0
# 1      0                           0     0        69.0           90.0
# 2      0                           0     0         NaN            NaN
# 3      0                           0     0        47.0           57.0
# 4      0                         NaN   NaN         NaN           78.0
# 5      0                           0   NaN        71.0           83.0
# 6      0                           0     0         0.0           95.0
# 7      0                           0     0        40.0           43.0
# 8      0                           0     0        64.0           64.0
# 9      0                           0     0         NaN           60.0
#
#    writing score        Date
# 0           74.0  03-13-2022
# 1           88.0  03-14-2022
# 2            NaN  03-15-2022
# 3           44.0  03-13-2022
# 4            NaN         NaN
# ...

# %%
# regex
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2 = df1.replace({'lunch':'[A-Za-z]'},0,regex=True)
df2.head(10)
# Out:
#    gender parental level of education lunch  math score  reading score  \
# 0  female           bachelor's degree     0        72.0           72.0
# 1  female                some college     0        69.0           90.0
# 2  female             master's degree     0         NaN            NaN
# 3    male          associate's degree     0        47.0           57.0
# 4    male                         NaN   NaN         NaN           78.0
# 5  female          associate's degree   NaN        71.0           83.0
# 6  female                some college     0         0.0           95.0
# 7    male                some college     0        40.0           43.0
# 8    male                 high school     0        64.0           64.0
# 9  female                 high school     0         NaN           60.0
#
#    writing score        Date
# 0           74.0  03-13-2022
# 1           88.0  03-14-2022
# 2            NaN  03-15-2022
# 3           44.0  03-13-2022
# 4            NaN         NaN
# ...

# %%
# regex
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2 = df1.replace('standard',method='bfill')
df2.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree  free/reduced        72.0
# 1  female                some college  free/reduced        69.0
# 2  female             master's degree  free/reduced         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female                some college  free/reduced         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %%
# regex
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2 = df1.replace('standard',method='bfill',limit=1)
df2.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree  free/reduced         NaN
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN         NaN
# 5  female          associate's degree           NaN        71.0
# 6  female                some college  free/reduced         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced         NaN
#
#    reading score  writing score        Date
# 0           72.0           74.0  03-13-2022
# 1           90.0           88.0  03-14-2022
# 2            NaN            NaN  03-15-2022
# 3           57.0           44.0  03-13-2022
# ...

# %% [markdown]
# #interpolate

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2 = df1.interpolate()
#df2 = df1.interpolate(method='linear')
df2.head(10)
# Out:
#    gender parental level of education         lunch  math score  \
# 0  female           bachelor's degree      standard        72.0
# 1  female                some college      standard        69.0
# 2  female             master's degree      standard        58.0
# 3    male          associate's degree  free/reduced        47.0
# 4    male                         NaN           NaN        59.0
# 5  female          associate's degree           NaN        71.0
# 6  female                some college      standard         0.0
# 7    male                some college  free/reduced        40.0
# 8    male                 high school  free/reduced        64.0
# 9  female                 high school  free/reduced        61.0
#
#    reading score  writing score        Date
# 0           72.0      74.000000  03-13-2022
# 1           90.0      88.000000  03-14-2022
# 2           73.5      66.000000  03-15-2022
# 3           57.0      44.000000  03-13-2022
# ...

# %%
# time-weighted interpolation only works on Series or DataFrames with a DatetimeIndex
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
df2 = df1.interpolate(method='time')
df2.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-24c1807702c3> in <module>()
#       1 # time-weighted interpolation only works on Series or DataFrames with a DatetimeIndex
#       2 df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv')
# ----> 3 df2 = df1.interpolate(method='time')
#       4 df2.head(10)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10718             limit_area,
#   10719             downcast,
# ...

# %%
type(df1.Date[0])
# Out:
# str

# %%
# 
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',parse_dates=['Date'])
type(df1.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',parse_dates=['Date'],index_col='Date')
df1.fillna({'Date':'03-12-2022'},inplace=True)
df1.replace('NaT','03-12-2022',inplace=True)
df1
# Out:
#             gender parental level of education         lunch  math score  \
# Date
# 2022-03-13  female           bachelor's degree      standard        72.0
# 2022-03-14  female                some college      standard        69.0
# 2022-03-15  female             master's degree      standard         NaN
# 2022-03-13    male          associate's degree  free/reduced        47.0
# NaT           male                         NaN           NaN         NaN
# 2022-03-15  female          associate's degree           NaN        71.0
# 2022-03-13  female                some college      standard         0.0
# 2022-03-14    male                some college  free/reduced        40.0
# 2022-03-15    male                 high school  free/reduced        64.0
# 2022-03-13  female                 high school  free/reduced         NaN
# 2022-03-14    male          associate's degree      standard        58.0
# 2022-03-15    male          associate's degree      standard        40.0
# ...

# %%
df2 = df1.interpolate(method='time')
df2.head(10)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-110-893c14943d00> in <module>()
# ----> 1 df2 = df1.interpolate(method='time')
#       2 df2.head(10)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10718             limit_area,
#   10719             downcast,
# > 10720             **kwargs,
#   10721         )
#   10722
#
# ...

# %%
df1.dtypes
# Out:
# gender                          object
# parental level of education     object
# lunch                           object
# math score                     float64
# reading score                  float64
# writing score                  float64
# dtype: object

# %%
df1.interpolate(limit=1)
# Out:
#             gender parental level of education         lunch  math score  \
# Date
# 2022-03-13  female           bachelor's degree      standard        72.0
# 2022-03-14  female                some college      standard        69.0
# 2022-03-15  female             master's degree      standard        58.0
# 2022-03-13    male          associate's degree  free/reduced        47.0
# NaT           male                         NaN           NaN        59.0
# 2022-03-15  female          associate's degree           NaN        71.0
# 2022-03-13  female                some college      standard         0.0
# 2022-03-14    male                some college  free/reduced        40.0
# 2022-03-15    male                 high school  free/reduced        64.0
# 2022-03-13  female                 high school  free/reduced        61.0
# 2022-03-14    male          associate's degree      standard        58.0
# 2022-03-15    male          associate's degree      standard        40.0
# ...

# %%
df1.interpolate(limit=1,limit_direction='backward')
# Out:
#             gender parental level of education         lunch  math score  \
# Date
# 2022-03-13  female           bachelor's degree      standard        72.0
# 2022-03-14  female                some college      standard        69.0
# 2022-03-15  female             master's degree      standard        58.0
# 2022-03-13    male          associate's degree  free/reduced        47.0
# NaT           male                         NaN           NaN        59.0
# 2022-03-15  female          associate's degree           NaN        71.0
# 2022-03-13  female                some college      standard         0.0
# 2022-03-14    male                some college  free/reduced        40.0
# 2022-03-15    male                 high school  free/reduced        64.0
# 2022-03-13  female                 high school  free/reduced        61.0
# 2022-03-14    male          associate's degree      standard        58.0
# 2022-03-15    male          associate's degree      standard        40.0
# ...

# %% [markdown]
# # loc

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/sg758253/AI/main/pandas/StudentsPerformance.csv',parse_dates=['Date'])
df1
# Out:
#     gender parental level of education         lunch  math score  \
# 0   female           bachelor's degree      standard        72.0
# 1   female                some college      standard        69.0
# 2   female             master's degree      standard         NaN
# 3     male          associate's degree  free/reduced        47.0
# 4     male                         NaN           NaN         NaN
# 5   female          associate's degree           NaN        71.0
# 6   female                some college      standard         0.0
# 7     male                some college  free/reduced        40.0
# 8     male                 high school  free/reduced        64.0
# 9   female                 high school  free/reduced         NaN
# 10    male          associate's degree      standard        58.0
# 11    male          associate's degree      standard        40.0
# 12  female                 high school      standard        65.0
# ...
